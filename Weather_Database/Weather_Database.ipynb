# %% [markdown]
# #### Module 6 Challenge
# **Deliverable 1: Retrieve Weather Data**
#
# Generate a set of 2,000 random latitudes and longitudes, retrieve the nearest city, and perform an API call with the OpenWeatherMap. In addition to the city weather data you gathered in this module, use your API skills to retrieve the current weather description for each city. Then, create a new DataFrame containing the updated weather data.

# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the request library
import requests
import time
from citipy import citipy
from datetime import datetime


# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats and longs to a list
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 619

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
# Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
# Add 1 to the record count.
    record_count += 1       
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
        
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | azrow
# City not found. Skipping...
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | saldanha
# Processing Record 6 of Set 1 | turukhansk
# Processing Record 7 of Set 1 | hanko
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | charters towers
# Processing Record 11 of Set 1 | dharur
# Processing Record 12 of Set 1 | san ramon
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | usinsk
# Processing Record 15 of Set 1 | bertoua
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | chimbote
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | dingle
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | vao
# Processing Record 24 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 1 | turayf
# Processing Record 26 of Set 1 | coquimbo
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | sulangan
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | puerto colombia
# Processing Record 32 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | gat
# Processing Record 35 of Set 1 | aklavik
# Processing Record 36 of Set 1 | muhos
# Processing Record 37 of Set 1 | kahului
# Processing Record 38 of Set 1 | pueblo nuevo
# Processing Record 39 of Set 1 | salalah
# Processing Record 40 of Set 1 | bilibino
# Processing Record 41 of Set 1 | vardo
# Processing Record 42 of Set 1 | zhangjiakou
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | paka
# Processing Record 47 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | hobart
# Processing Record 1 of Set 2 | namibe
# Processing Record 2 of Set 2 | norman wells
# Processing Record 3 of Set 2 | kulhudhuffushi
# Processing Record 4 of Set 2 | burica
# City not found. Skipping...
# Processing Record 5 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 2 | glebychevo
# Processing Record 7 of Set 2 | tuktoyaktuk
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | mahebourg
# Processing Record 10 of Set 2 | kupang
# Processing Record 11 of Set 2 | timra
# Processing Record 12 of Set 2 | port-gentil
# Processing Record 13 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 2 | beringovskiy
# Processing Record 15 of Set 2 | hibbing
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | mehamn
# Processing Record 18 of Set 2 | souillac
# Processing Record 19 of Set 2 | vilyuysk
# Processing Record 20 of Set 2 | bubaque
# Processing Record 21 of Set 2 | bathsheba
# Processing Record 22 of Set 2 | coihaique
# Processing Record 23 of Set 2 | san andres
# Processing Record 24 of Set 2 | miranda
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | praya
# Processing Record 27 of Set 2 | kaitangata
# Processing Record 28 of Set 2 | songea
# Processing Record 29 of Set 2 | arona
# Processing Record 30 of Set 2 | sur
# Processing Record 31 of Set 2 | ahipara
# Processing Record 32 of Set 2 | constitucion
# Processing Record 33 of Set 2 | antalaha
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | kununurra
# Processing Record 36 of Set 2 | koppal
# Processing Record 37 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 2 | bambous virieux
# Processing Record 39 of Set 2 | bonavista
# Processing Record 40 of Set 2 | osmena
# Processing Record 41 of Set 2 | sioux lookout
# Processing Record 42 of Set 2 | ushuaia
# Processing Record 43 of Set 2 | te anau
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | gobabis
# Processing Record 46 of Set 2 | puerto lempira
# Processing Record 47 of Set 2 | nantucket
# Processing Record 48 of Set 2 | olafsvik
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | clyde river
# Processing Record 1 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 3 | grindavik
# Processing Record 5 of Set 3 | camacha
# Processing Record 6 of Set 3 | avera
# Processing Record 7 of Set 3 | gushikawa
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | ankazobe
# Processing Record 10 of Set 3 | nzerekore
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | san patricio
# Processing Record 13 of Set 3 | ahuimanu
# Processing Record 14 of Set 3 | toledo
# Processing Record 15 of Set 3 | novobiryusinskiy
# Processing Record 16 of Set 3 | isangel
# Processing Record 17 of Set 3 | kropotkin
# Processing Record 18 of Set 3 | samarai
# Processing Record 19 of Set 3 | sao filipe
# Processing Record 20 of Set 3 | hofn
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | saint george
# Processing Record 23 of Set 3 | turkistan
# Processing Record 24 of Set 3 | dudinka
# Processing Record 25 of Set 3 | los llanos de aridane
# Processing Record 26 of Set 3 | yaring
# Processing Record 27 of Set 3 | harper
# Processing Record 28 of Set 3 | energetik
# Processing Record 29 of Set 3 | weyburn
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | mangrol
# Processing Record 32 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 3 | khatanga
# Processing Record 34 of Set 3 | araouane
# Processing Record 35 of Set 3 | severo-kurilsk
# Processing Record 36 of Set 3 | cape town
# Processing Record 37 of Set 3 | mpwapwa
# Processing Record 38 of Set 3 | inhambane
# Processing Record 39 of Set 3 | ensley
# Processing Record 40 of Set 3 | japura
# Processing Record 41 of Set 3 | loreto
# Processing Record 42 of Set 3 | kapaa
# Processing Record 43 of Set 3 | strezhevoy
# Processing Record 44 of Set 3 | thompson
# Processing Record 45 of Set 3 | ponta do sol
# Processing Record 46 of Set 3 | saint-philippe
# Processing Record 47 of Set 3 | zaysan
# Processing Record 48 of Set 3 | butaritari
# Processing Record 49 of Set 3 | nouadhibou
# Processing Record 50 of Set 3 | bengkulu
# Processing Record 1 of Set 4 | mataura
# Processing Record 2 of Set 4 | carutapera
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 4 | somerset east
# Processing Record 6 of Set 4 | byron bay
# Processing Record 7 of Set 4 | antofagasta
# Processing Record 8 of Set 4 | brae
# Processing Record 9 of Set 4 | port elizabeth
# Processing Record 10 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 4 | ballitoville
# Processing Record 12 of Set 4 | krasnoselkup
# Processing Record 13 of Set 4 | del rio
# Processing Record 14 of Set 4 | alba
# Processing Record 15 of Set 4 | nyon
# Processing Record 16 of Set 4 | mildura
# Processing Record 17 of Set 4 | roanoke
# Processing Record 18 of Set 4 | krasnyy yar
# Processing Record 19 of Set 4 | kodiak
# Processing Record 20 of Set 4 | kloulklubed
# Processing Record 21 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 4 | show low
# Processing Record 23 of Set 4 | wenling
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | xiongshi
# City not found. Skipping...
# Processing Record 26 of Set 4 | takoradi
# Processing Record 27 of Set 4 | biskamzha
# Processing Record 28 of Set 4 | evensk
# Processing Record 29 of Set 4 | dunedin
# Processing Record 30 of Set 4 | yulara
# Processing Record 31 of Set 4 | tocopilla
# Processing Record 32 of Set 4 | hasaki
# Processing Record 33 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 4 | luderitz
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | cherskiy
# Processing Record 37 of Set 4 | kavieng
# Processing Record 38 of Set 4 | pangai
# Processing Record 39 of Set 4 | rawson
# Processing Record 40 of Set 4 | sooke
# Processing Record 41 of Set 4 | port alfred
# Processing Record 42 of Set 4 | lata
# Processing Record 43 of Set 4 | bethel
# Processing Record 44 of Set 4 | canyon
# Processing Record 45 of Set 4 | airai
# Processing Record 46 of Set 4 | nyurba
# Processing Record 47 of Set 4 | amapa
# Processing Record 48 of Set 4 | fairlie
# Processing Record 49 of Set 4 | karpathos
# Processing Record 50 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 5 | chachapoyas
# Processing Record 2 of Set 5 | ust-kut
# Processing Record 3 of Set 5 | lasa
# Processing Record 4 of Set 5 | faya
# Processing Record 5 of Set 5 | marfino
# Processing Record 6 of Set 5 | moanda
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | banda aceh
# Processing Record 9 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 5 | yumen
# Processing Record 12 of Set 5 | sisimiut
# Processing Record 13 of Set 5 | dumas
# Processing Record 14 of Set 5 | greymouth
# Processing Record 15 of Set 5 | sao jose da coroa grande
# Processing Record 16 of Set 5 | songjianghe
# Processing Record 17 of Set 5 | fortuna
# Processing Record 18 of Set 5 | labuhan
# Processing Record 19 of Set 5 | san quintin
# Processing Record 20 of Set 5 | yar-sale
# Processing Record 21 of Set 5 | longyearbyen
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | polotnyanyy zavod
# Processing Record 24 of Set 5 | jacareacanga
# Processing Record 25 of Set 5 | paamiut
# Processing Record 26 of Set 5 | pangnirtung
# Processing Record 27 of Set 5 | minudasht
# Processing Record 28 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 5 | cortes
# Processing Record 30 of Set 5 | lapua
# Processing Record 31 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 32 of Set 5 | bitung
# Processing Record 33 of Set 5 | kamenka
# Processing Record 34 of Set 5 | karratha
# Processing Record 35 of Set 5 | sitka
# Processing Record 36 of Set 5 | thanh hoa
# Processing Record 37 of Set 5 | viedma
# Processing Record 38 of Set 5 | bintulu
# Processing Record 39 of Set 5 | kostino
# Processing Record 40 of Set 5 | filingue
# Processing Record 41 of Set 5 | baiyin
# Processing Record 42 of Set 5 | sapa
# Processing Record 43 of Set 5 | nabire
# Processing Record 44 of Set 5 | amga
# Processing Record 45 of Set 5 | pisco
# Processing Record 46 of Set 5 | east london
# Processing Record 47 of Set 5 | henties bay
# Processing Record 48 of Set 5 | mount isa
# Processing Record 49 of Set 5 | qandala
# Processing Record 50 of Set 5 | george town
# Processing Record 1 of Set 6 | ous
# Processing Record 2 of Set 6 | new norfolk
# Processing Record 3 of Set 6 | aguimes
# Processing Record 4 of Set 6 | tiksi
# Processing Record 5 of Set 6 | ye
# City not found. Skipping...
# Processing Record 6 of Set 6 | puri
# Processing Record 7 of Set 6 | cabo san lucas
# Processing Record 8 of Set 6 | petropavlovka
# Processing Record 9 of Set 6 | dongzhen
# Processing Record 10 of Set 6 | wasilla
# Processing Record 11 of Set 6 | melendugno
# Processing Record 12 of Set 6 | mayahi
# Processing Record 13 of Set 6 | valparaiso
# Processing Record 14 of Set 6 | challans
# Processing Record 15 of Set 6 | saint-pierre
# Processing Record 16 of Set 6 | udachnyy
# Processing Record 17 of Set 6 | bulolo
# Processing Record 18 of Set 6 | ndende
# Processing Record 19 of Set 6 | kyra
# Processing Record 20 of Set 6 | sambava
# Processing Record 21 of Set 6 | xining
# Processing Record 22 of Set 6 | ballina
# Processing Record 23 of Set 6 | leh
# Processing Record 24 of Set 6 | kavaratti
# Processing Record 25 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 6 | alice springs
# Processing Record 27 of Set 6 | alofi
# Processing Record 28 of Set 6 | marzuq
# Processing Record 29 of Set 6 | tautira
# Processing Record 30 of Set 6 | kapoeta
# Processing Record 31 of Set 6 | atambua
# Processing Record 32 of Set 6 | xadani
# City not found. Skipping...
# Processing Record 33 of Set 6 | oussouye
# Processing Record 34 of Set 6 | necochea
# Processing Record 35 of Set 6 | sanwer
# Processing Record 36 of Set 6 | kadoma
# Processing Record 37 of Set 6 | omsukchan
# Processing Record 38 of Set 6 | jinchang
# Processing Record 39 of Set 6 | vuktyl
# Processing Record 40 of Set 6 | nargana
# Processing Record 41 of Set 6 | aykhal
# Processing Record 42 of Set 6 | asau
# Processing Record 43 of Set 6 | emba
# Processing Record 44 of Set 6 | madera
# Processing Record 45 of Set 6 | faanui
# Processing Record 46 of Set 6 | ostrovnoy
# Processing Record 47 of Set 6 | gorele
# Processing Record 48 of Set 6 | bam
# Processing Record 49 of Set 6 | palmer
# Processing Record 50 of Set 6 | tankhoy
# Processing Record 1 of Set 7 | broome
# Processing Record 2 of Set 7 | jalu
# Processing Record 3 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 7 | nanortalik
# Processing Record 5 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 7 | flinders
# Processing Record 7 of Set 7 | chicama
# Processing Record 8 of Set 7 | devils lake
# Processing Record 9 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 7 | mabaruma
# Processing Record 11 of Set 7 | kadi
# Processing Record 12 of Set 7 | chuy
# Processing Record 13 of Set 7 | qiqihar
# Processing Record 14 of Set 7 | parana
# Processing Record 15 of Set 7 | victoria
# Processing Record 16 of Set 7 | douglas
# Processing Record 17 of Set 7 | marica
# Processing Record 18 of Set 7 | marawi
# Processing Record 19 of Set 7 | dali
# Processing Record 20 of Set 7 | aksarka
# Processing Record 21 of Set 7 | puerto escondido
# Processing Record 22 of Set 7 | betanzos
# Processing Record 23 of Set 7 | esil
# Processing Record 24 of Set 7 | nome
# Processing Record 25 of Set 7 | bereda
# Processing Record 26 of Set 7 | acapulco
# Processing Record 27 of Set 7 | merauke
# Processing Record 28 of Set 7 | meulaboh
# Processing Record 29 of Set 7 | esperance
# Processing Record 30 of Set 7 | los reyes
# Processing Record 31 of Set 7 | bad waldsee
# Processing Record 32 of Set 7 | mursalimkino
# Processing Record 33 of Set 7 | sept-iles
# Processing Record 34 of Set 7 | oxford
# Processing Record 35 of Set 7 | yuzhno-kurilsk
# Processing Record 36 of Set 7 | naze
# Processing Record 37 of Set 7 | dalvik
# Processing Record 38 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 39 of Set 7 | deming
# Processing Record 40 of Set 7 | fairbanks
# Processing Record 41 of Set 7 | okoneshnikovo
# Processing Record 42 of Set 7 | uige
# Processing Record 43 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 7 | schoneiche
# Processing Record 45 of Set 7 | panaba
# Processing Record 46 of Set 7 | galesong
# Processing Record 47 of Set 7 | sterling
# Processing Record 48 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 49 of Set 7 | corpus christi
# Processing Record 50 of Set 7 | la ronge
# Processing Record 1 of Set 8 | mizan teferi
# Processing Record 2 of Set 8 | maridi
# Processing Record 3 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 8 | tadine
# Processing Record 5 of Set 8 | kieta
# Processing Record 6 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 8 | yaypan
# Processing Record 8 of Set 8 | celestun
# Processing Record 9 of Set 8 | rocha
# Processing Record 10 of Set 8 | moose factory
# Processing Record 11 of Set 8 | kolobrzeg
# Processing Record 12 of Set 8 | olinda
# Processing Record 13 of Set 8 | ancud
# Processing Record 14 of Set 8 | saint-augustin
# Processing Record 15 of Set 8 | sao joao da barra
# Processing Record 16 of Set 8 | seredka
# Processing Record 17 of Set 8 | suntar
# Processing Record 18 of Set 8 | alegrete
# Processing Record 19 of Set 8 | kenora
# Processing Record 20 of Set 8 | boa vista
# Processing Record 21 of Set 8 | cairns
# Processing Record 22 of Set 8 | sechura
# Processing Record 23 of Set 8 | biak
# Processing Record 24 of Set 8 | mujiayingzi
# Processing Record 25 of Set 8 | yeppoon
# Processing Record 26 of Set 8 | richards bay
# Processing Record 27 of Set 8 | bilma
# Processing Record 28 of Set 8 | tura
# Processing Record 29 of Set 8 | pyu
# Processing Record 30 of Set 8 | hervey bay
# Processing Record 31 of Set 8 | canton
# Processing Record 32 of Set 8 | tete
# Processing Record 33 of Set 8 | codrington
# Processing Record 34 of Set 8 | pangoa
# Processing Record 35 of Set 8 | mahuva
# Processing Record 36 of Set 8 | topeka
# Processing Record 37 of Set 8 | derzhavinsk
# Processing Record 38 of Set 8 | planaltina
# Processing Record 39 of Set 8 | ishigaki
# Processing Record 40 of Set 8 | vila do maio
# Processing Record 41 of Set 8 | grand-santi
# Processing Record 42 of Set 8 | shunyi
# Processing Record 43 of Set 8 | sydney
# Processing Record 44 of Set 8 | narasannapeta
# Processing Record 45 of Set 8 | romitan
# Processing Record 46 of Set 8 | port hedland
# Processing Record 47 of Set 8 | aras
# Processing Record 48 of Set 8 | semey
# Processing Record 49 of Set 8 | upernavik
# Processing Record 50 of Set 8 | ixtapa
# Processing Record 1 of Set 9 | fulitun
# City not found. Skipping...
# Processing Record 2 of Set 9 | atbasar
# Processing Record 3 of Set 9 | vilhena
# Processing Record 4 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 5 of Set 9 | waiouru
# Processing Record 6 of Set 9 | pocone
# Processing Record 7 of Set 9 | tupik
# Processing Record 8 of Set 9 | husavik
# Processing Record 9 of Set 9 | lorengau
# Processing Record 10 of Set 9 | inirida
# Processing Record 11 of Set 9 | najran
# Processing Record 12 of Set 9 | minas
# Processing Record 13 of Set 9 | xinmin
# Processing Record 14 of Set 9 | keetmanshoop
# Processing Record 15 of Set 9 | lamu
# Processing Record 16 of Set 9 | egvekinot
# Processing Record 17 of Set 9 | salinas
# Processing Record 18 of Set 9 | mount gambier
# Processing Record 19 of Set 9 | lagoa
# Processing Record 20 of Set 9 | adeje
# Processing Record 21 of Set 9 | axim
# Processing Record 22 of Set 9 | la asuncion
# Processing Record 23 of Set 9 | bassano
# Processing Record 24 of Set 9 | katsuura
# Processing Record 25 of Set 9 | jumla
# Processing Record 26 of Set 9 | leo
# Processing Record 27 of Set 9 | shimoda
# Processing Record 28 of Set 9 | kozyatyn
# Processing Record 29 of Set 9 | alyangula
# Processing Record 30 of Set 9 | maningrida
# Processing Record 31 of Set 9 | berlevag
# Processing Record 32 of Set 9 | tarrafal
# Processing Record 33 of Set 9 | rio gallegos
# Processing Record 34 of Set 9 | portland
# Processing Record 35 of Set 9 | houma
# Processing Record 36 of Set 9 | umm lajj
# Processing Record 37 of Set 9 | kihei
# Processing Record 38 of Set 9 | hamilton
# Processing Record 39 of Set 9 | pemba
# Processing Record 40 of Set 9 | nanakuli
# Processing Record 41 of Set 9 | quatre cocos
# Processing Record 42 of Set 9 | rantauprapat
# Processing Record 43 of Set 9 | praia
# Processing Record 44 of Set 9 | igrim
# Processing Record 45 of Set 9 | carahue
# Processing Record 46 of Set 9 | artemisa
# Processing Record 47 of Set 9 | dryden
# Processing Record 48 of Set 9 | tabas
# Processing Record 49 of Set 9 | santa maria del oro
# Processing Record 50 of Set 9 | xuddur
# Processing Record 1 of Set 10 | lokoja
# Processing Record 2 of Set 10 | rio grande
# Processing Record 3 of Set 10 | zhigansk
# Processing Record 4 of Set 10 | kedrovyy
# Processing Record 5 of Set 10 | kampot
# Processing Record 6 of Set 10 | margate
# Processing Record 7 of Set 10 | caucaia
# Processing Record 8 of Set 10 | pavlodar
# Processing Record 9 of Set 10 | san policarpo
# Processing Record 10 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 11 of Set 10 | chapleau
# Processing Record 12 of Set 10 | tessalit
# Processing Record 13 of Set 10 | nioro
# Processing Record 14 of Set 10 | bulgan
# Processing Record 15 of Set 10 | namatanai
# Processing Record 16 of Set 10 | port lincoln
# Processing Record 17 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 10 | lewistown
# Processing Record 19 of Set 10 | port hardy
# Processing Record 20 of Set 10 | shache
# Processing Record 21 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 22 of Set 10 | livno
# Processing Record 23 of Set 10 | mitsamiouli
# Processing Record 24 of Set 10 | batemans bay
# Processing Record 25 of Set 10 | safwah
# City not found. Skipping...
# Processing Record 26 of Set 10 | naro
# Processing Record 27 of Set 10 | homer
# Processing Record 28 of Set 10 | mayumba
# Processing Record 29 of Set 10 | atasu
# Processing Record 30 of Set 10 | zhitikara
# City not found. Skipping...
# Processing Record 31 of Set 10 | eureka
# Processing Record 32 of Set 10 | poum
# Processing Record 33 of Set 10 | altyn-topkan
# Processing Record 34 of Set 10 | norman
# Processing Record 35 of Set 10 | nalut
# Processing Record 36 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 37 of Set 10 | nortelandia
# Processing Record 38 of Set 10 | buala
# Processing Record 39 of Set 10 | kruisfontein
# Processing Record 40 of Set 10 | nakhon phanom
# Processing Record 41 of Set 10 | burkhala
# City not found. Skipping...
# Processing Record 42 of Set 10 | warrnambool
# Processing Record 43 of Set 10 | tigil
# Processing Record 44 of Set 10 | mirnyy
# Processing Record 45 of Set 10 | solnechnyy
# Processing Record 46 of Set 10 | bani
# Processing Record 47 of Set 10 | vadgaon
# Processing Record 48 of Set 10 | vostok
# Processing Record 49 of Set 10 | ajaccio
# Processing Record 50 of Set 10 | newport
# Processing Record 1 of Set 11 | belmonte
# Processing Record 2 of Set 11 | arlit
# Processing Record 3 of Set 11 | kendari
# Processing Record 4 of Set 11 | roma
# Processing Record 5 of Set 11 | minna
# Processing Record 6 of Set 11 | benguela
# Processing Record 7 of Set 11 | dzhida
# Processing Record 8 of Set 11 | guozhen
# Processing Record 9 of Set 11 | mtama
# Processing Record 10 of Set 11 | ola
# Processing Record 11 of Set 11 | colares
# Processing Record 12 of Set 11 | kushmurun
# Processing Record 13 of Set 11 | mananara
# Processing Record 14 of Set 11 | comodoro rivadavia
# Processing Record 15 of Set 11 | lengshuitan
# Processing Record 16 of Set 11 | hami
# Processing Record 17 of Set 11 | vanimo
# Processing Record 18 of Set 11 | tual
# Processing Record 19 of Set 11 | champerico
# Processing Record 20 of Set 11 | beira
# Processing Record 21 of Set 11 | jizan
# Processing Record 22 of Set 11 | broken hill
# Processing Record 23 of Set 11 | tukrah
# Processing Record 24 of Set 11 | gusau
# Processing Record 25 of Set 11 | barsovo
# Processing Record 26 of Set 11 | shitanjing
# Processing Record 27 of Set 11 | minsk
# Processing Record 28 of Set 11 | pacific grove
# Processing Record 29 of Set 11 | ilulissat
# Processing Record 30 of Set 11 | zhicheng
# Processing Record 31 of Set 11 | pokhara
# Processing Record 32 of Set 11 | semirom
# Processing Record 33 of Set 11 | tuburan
# Processing Record 34 of Set 11 | narsaq
# Processing Record 35 of Set 11 | grand gaube
# Processing Record 36 of Set 11 | berbera
# Processing Record 37 of Set 11 | dalbandin
# Processing Record 38 of Set 11 | dodge city
# Processing Record 39 of Set 11 | fort-shevchenko
# Processing Record 40 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 41 of Set 11 | necocli
# Processing Record 42 of Set 11 | gravelbourg
# Processing Record 43 of Set 11 | nosy varika
# Processing Record 44 of Set 11 | marsh harbour
# Processing Record 45 of Set 11 | linkou
# Processing Record 46 of Set 11 | kharp
# Processing Record 47 of Set 11 | cayenne
# Processing Record 48 of Set 11 | tarko-sale
# Processing Record 49 of Set 11 | sabalgarh
# Processing Record 50 of Set 11 | muros
# Processing Record 1 of Set 12 | ngunguru
# Processing Record 2 of Set 12 | surt
# Processing Record 3 of Set 12 | port blair
# Processing Record 4 of Set 12 | khunzakh
# Processing Record 5 of Set 12 | terrace bay
# Processing Record 6 of Set 12 | nemuro
# Processing Record 7 of Set 12 | scottsbluff
# Processing Record 8 of Set 12 | puerto del rosario
# Processing Record 9 of Set 12 | vitim
# Processing Record 10 of Set 12 | imeni poliny osipenko
# Processing Record 11 of Set 12 | luancheng
# Processing Record 12 of Set 12 | molteno
# Processing Record 13 of Set 12 | barstow
# Processing Record 14 of Set 12 | chinsali
# Processing Record 15 of Set 12 | charyshskoye
# Processing Record 16 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 17 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 18 of Set 12 | douentza
# Processing Record 19 of Set 12 | komsomolskiy
# Processing Record 20 of Set 12 | midland
# Processing Record 21 of Set 12 | san pedro
# Processing Record 22 of Set 12 | indi
# Processing Record 23 of Set 12 | maitum
# Processing Record 24 of Set 12 | finschhafen
# Processing Record 25 of Set 12 | sarh
# Processing Record 26 of Set 12 | kasane
# Processing Record 27 of Set 12 | ravar
# Processing Record 28 of Set 12 | kushiro
# Processing Record 29 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 12 | pombas
# Processing Record 31 of Set 12 | berwick
# Processing Record 32 of Set 12 | great falls
# Processing Record 33 of Set 12 | katesh
# Processing Record 34 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 35 of Set 12 | kajaani
# Processing Record 36 of Set 12 | opuwo
# Processing Record 37 of Set 12 | anito
# Processing Record 38 of Set 12 | puerto carreno
# Processing Record 39 of Set 12 | aksay
# Processing Record 40 of Set 12 | havelock
# Processing Record 41 of Set 12 | correntina
# Processing Record 42 of Set 12 | guelengdeng
# City not found. Skipping...
# Processing Record 43 of Set 12 | kharan
# Processing Record 44 of Set 12 | iquitos
# Processing Record 45 of Set 12 | dossor
# Processing Record 46 of Set 12 | goure
# Processing Record 47 of Set 12 | shahr-e babak
# Processing Record 48 of Set 12 | boyarka
# Processing Record 49 of Set 12 | guaraciaba do norte
# Processing Record 50 of Set 12 | nurota
# Processing Record 1 of Set 13 | inta
# Processing Record 2 of Set 13 | deputatskiy
# Processing Record 3 of Set 13 | darnah
# Processing Record 4 of Set 13 | mudgee
# Processing Record 5 of Set 13 | druzhba
# Processing Record 6 of Set 13 | churachandpur
# Processing Record 7 of Set 13 | udalguri
# Processing Record 8 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 13 | denpasar
# Processing Record 10 of Set 13 | hengyang
# Processing Record 11 of Set 13 | bandarbeyla
# Processing Record 12 of Set 13 | guadalupe y calvo
# Processing Record 13 of Set 13 | adrar
# Processing Record 14 of Set 13 | dawlatabad
# Processing Record 15 of Set 13 | baoshan
# Processing Record 16 of Set 13 | saint anthony
# Processing Record 17 of Set 13 | port moresby
# Processing Record 18 of Set 13 | bac lieu
# Processing Record 19 of Set 13 | lompoc
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 569

# %%
# Convert the list of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Hilo      US  19.7297 -155.0900     72.28        77          20
# 1           Albany      US  42.6001  -73.9662     69.03        84          98
# 2      Provideniya      RU  64.3833 -173.3000     37.38        78          31
# 3         Saldanha      ZA -33.0117   17.9442     62.65        78           0
# 4       Turukhansk      RU  65.8167   87.9833     31.73        65          83
# 5            Hanko      FI  59.8333   22.9500     51.06        69         100
# 6     Punta Arenas      CL -53.1500  -70.9167     50.11        43          75
# 7        Busselton      AU -33.6500  115.3333     57.15        75           3
# 8  Charters Towers      AU -20.1000  146.2667     66.16        97           8
# 9           Dharur      IN  18.8167   76.1167     71.47        86         100
#
#    Wind Speed Current Description
# 0        8.05          few clouds
# 1        1.99     overcast clouds
# 2        0.92    scattered clouds
# 3       12.53           clear sky
# 4        3.89       broken clouds
# 5       15.35     overcast clouds
# 6       11.50       broken clouds
# 7       14.34           clear sky
# 8       12.55           clear sky
# 9       10.13     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
